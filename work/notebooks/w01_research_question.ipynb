# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nhatle16/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/nhatle16/flyrank-ml-internship.git
# !ls /content/flyrank-ml-internship/data/raw
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.
# content_refresh_anonymized.csv

# %%
# Loading the dataset
import pandas as pd, numpy as np
df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")
print(df.shape[0], "rows,", df.shape[1], "columns")
# Out:
# 30000 rows, 44 columns

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My selected lane is **Ranking Signal Analysis**. I chose this lane because I want to understand which measurable characteristics of the content and historical search performance are most strongly associated with organic search outcomes. Instead of building a predictive model, I want to investigate which signals appear consistently useful, quantify their relationships with performance, and determine whether these signals can support better prioritization and analysis of content. Therefore, better business decisions can be made.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(f"Dataset shape: {df.shape}")
print(f"Number of columns: {df.shape[1]}")

print("\nColumns available for analysis:")
for column in df.columns:
    print(f"- {column}")
# Out:
# Dataset shape: (30000, 44)
# Number of columns: 44
#
# Columns available for analysis:
# - content_id
# - client_id
# - search_volume
# - competition
# - competition_level
# - cpc
# - content_type
# - main_intent
# - word_count
# - char_count
# - provider_used
# - model_used
# - impressions_90d
# - clicks_90d
# - pageviews_90d
# - sessions_90d
# - users_90d
# - engaged_sessions_90d
# - ai_sessions_90d
# - scroll_events_90d
# - days_with_impressions
# - days_with_sessions
# - impressions_last_30d
# - clicks_last_30d
# - sessions_last_30d
# - impressions_prev_30d
# - clicks_prev_30d
# - sessions_prev_30d
# - content_age_days
# - age_tier
# - age_tier_order
# - days_since_last_update
# - freshness_tier
# - word_count_tier
# - char_count_tier
# - ctr
# - avg_position
# - engagement_rate
# - scroll_rate
# - ai_traffic_pct
# - impression_tier
# - position_tier
# - trend_direction
# - trend_pct

# %% [markdown]
# From these available characteristics, the potentially strong candidates for signal analysis are: `content_type`, `main_intent`, `word_count`, `char_count`, `content_age_days`, `days_since_last_update`, `age_tier`,... These features are very natural for Ranking Signal Analysis.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# - My analysis is intended to improve which content signals should be considered when evaluating and prioritizing pages.
#
# - SEO and content teams could use these findings to focus their investigation on pages or content characteristics associated with stronger or weaker search performance.
#
# - A wrong recommendation could lead to time being spent on low-value pages and overlook higher-value opportunities, or draw misleading conclusions about which content characteristics are worth investigating.
#
# The dataset contains substantial variation in measured search performance across observations. This makes it possible to investigate whether differences in available content and historical performance signals are associated with different search outcomes. The resulting analysis could support SEO and content teams when deciding which signals or pages warrant further investigation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df.head()
df.describe(include="all").T
# Out:
#                           count unique                     top   freq  \
# content_id                30000  30000    content_6880eb215048      1
# client_id                 30000     32       client_19581e27de   7008
# search_volume           27532.0    NaN                     NaN    NaN
# competition             27532.0    NaN                     NaN    NaN
# competition_level         27390      3                     LOW  22896
# cpc                     27532.0    NaN                     NaN    NaN
# content_type              30000      3         keyword article  27207
# main_intent               27626      4           informational  17235
# word_count              22301.0    NaN                     NaN    NaN
# char_count              22301.0    NaN                     NaN    NaN
# provider_used              8562      2                  google   7364
# model_used                24267      5  gemini-3-flash-preview  13271
# ...

# %%
# Performance metrics relevant to the Ranking Signal Analysis lane
performance_columns = [
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "scroll_rate",
]

performance_summary = df[performance_columns].describe().T

display(performance_summary)
# Out:
#                    count         mean           std  min   25%     50%  \
# impressions_90d  30000.0  5200.366300  16838.019547  1.0  81.0  731.00
# clicks_90d       30000.0    16.097333     75.076958  0.0   0.0    1.00
# sessions_90d     30000.0    37.066633    107.069131  1.0   2.0    7.00
# ctr              30000.0     0.510733      3.279162  0.0   0.0    0.07
# avg_position     30000.0    16.342380     15.216790  0.0   6.2   10.80
# engagement_rate  30000.0     2.534520      8.310096  0.0   0.0    0.00
# scroll_rate      29875.0    18.212921     29.472768  0.0   0.0    5.00
#
#                      75%       max
# impressions_90d  3615.25  517715.0
# clicks_90d          7.00    4178.0
# sessions_90d       27.00    4345.0
# ctr                 0.29     100.0
# avg_position       22.30     245.0
# engagement_rate     1.35     100.0
# scroll_rate        23.53     300.0

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# - The starter dataset consists of 30000 rows and 44 columns. It has enough information to investigate the relationship between content characteristics and performance, also plenty of potentially many measurable signals for analysis.
#
# - Looking at the dataset, there are many content characteristics that are worth to investigate to understand their impacts to search performance. For example, features such as `main_intent`, `word_count`, `char_count`, `engagement_rate`, `scroll_rate`, etc. may provide meaningful signals about differences in search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(df.shape[0], "rows,", df.shape[1], "columns")
df.head(5).T
# Out:
# 30000 rows, 44 columns
#                                            0                       1  \
# content_id              content_304f48230142    content_a1fb4e703a9e
# client_id                  client_f369cb89fc       client_4e07408562
# search_volume                           10.0                    90.0
# competition                             0.67                    0.01
# competition_level                       HIGH                     LOW
# cpc                                     2.05                    0.05
# content_type                 keyword article         keyword article
# main_intent                    transactional           informational
# word_count                            3221.0                  2481.0
# char_count                           20457.0                 15562.0
# provider_used                            NaN                     NaN
# model_used                  gemini-2.5-flash  gemini-3-flash-preview
# ...

# %%
print(len(df[df[""]]))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My analysis will be able to observe and measure relationships between content/search signals and search performance within the dataset. It will provide directional insights into which signals are associated with stronger or weaker performance and may provide decision-support for SEO and content teams when prioritizing pages or areas for further investigation.
#
# However, the analysis will not establish causal relationships, prove that any particular variable is a Google ranking factor, or predict how Google will rank a page in the future. A relationship observed in this dataset does not guarantee that changing a signal will improve search performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
